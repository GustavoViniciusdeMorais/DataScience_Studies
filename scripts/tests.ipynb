# %%
# %%bash
# pip -q install trl
# pip -q install peft
# pip -q install torch
# pip -q install datasets
# pip -q install transformers

# %%
# after training, try to load the model like the following
# import os
# # Load the trained model
# model_path = os.path.abspath('image_classifier_model.h5')
# model = load_model(model_path)

# %%
import torch
from trl import SFTTrainer
from datasets import load_dataset
from peft import LoraConfig, get_peft_model, prepare_model_for_int8_training
from transformers import AutoModelForCausalLM, AutoTokenizer, TrainingArguments
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 4
#       2 from trl import SFTTrainer
#       3 from datasets import load_dataset
# ----> 4 from peft import LoraConfig, get_peft_model, prepare_model_for_int8_training
#       5 from transformers import AutoModelForCausalLM, AutoTokenizer, TrainingArguments
#
# ImportError: cannot import name 'prepare_model_for_int8_training' from 'peft' (/opt/conda/lib/python3.11/site-packages/peft/__init__.py)
